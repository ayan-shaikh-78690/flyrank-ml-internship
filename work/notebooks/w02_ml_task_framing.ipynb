# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ayan-shaikh-78690/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# ### Lane 2: Refresh / Content Opportunity Scoring
#
# **ML task type: Ranking / Scoring**
#
# Our business question is: which content pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?
#
# This is a ranking/scoring problem because the main output is not simply a yes/no decision. The goal is to assign pages a priority score and rank them so that a content or SEO reviewer can examine the highest-priority pages first.
#
# The output will support a ranked review queue. A human reviewer can then decide the appropriate action for each page rather than treating the score as an automatic instruction.

# %%
# The task type is ranking/scoring because the output will prioritize pages for review.
print("ML task type: Ranking / Scoring")
# Out:
# ML task type: Ranking / Scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# ### Target / Proxy
#
# For the starter dataset, I will use `is_declining_label` as a **proxy target**.
#
# The proxy is defined as:
#
# `is_declining_label = (trend_direction == "down")`
#
# This proxy identifies content items that are currently showing a downward trend. It is useful for demonstrating the ML workflow, but it is not a perfect future-outcome target because `trend_direction` is calculated from the current observation window.
#
# A stronger future-looking target for later warehouse work would use a prior feature window to predict an observed outcome in a later window, such as whether traffic declines or recovers over the following 30 days.
#
# The model should therefore be interpreted as decision support for review prioritization, not as proof that refreshing a declining page will cause recovery.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
